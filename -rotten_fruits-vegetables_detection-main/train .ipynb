# %%
import warnings
import keras
from keras import models,layers,Sequential, losses,metrics,optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# Out:
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)
# Using TensorFlow backend.

# %%
batch_size = 64
num_classes = 8
epochs = 50
model_name = "project0.h5"
save_path = ""

path_to_train = "training"
path_to_test = "testing"

#load dataset
Generator = ImageDataGenerator()
train_data = Generator.flow_from_directory(path_to_train, (100, 100), batch_size=batch_size)
test_data = Generator.flow_from_directory(path_to_test, (100, 100), batch_size=batch_size)

model = Sequential()

model.add(Conv2D(16, (5, 5), input_shape=(100, 100, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(64, (5, 5),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(8, activation="softmax"))
model.summary()

#compile the model
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

#train the model
model.fit_generator(train_data,
                    steps_per_epoch=1000//batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_data, validation_steps = 3)

model.save(model_name)
# Out:
# Found 10805 images belonging to 8 classes.
# Found 194 images belonging to 8 classes.
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 96, 96, 16)        1216
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 48, 48, 16)        0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 48, 48, 16)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 44, 44, 32)        12832
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 22, 22, 32)        0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 18, 18, 64)        51264
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 5, 5, 128)         204928
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 8)                 2056
# =================================================================
# Total params: 1,060,008
# Trainable params: 1,060,008
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 15/15 [==============================] - 34s 2s/step - loss: 26.4438 - accuracy: 0.1327 - val_loss: 1.9235 - val_accuracy: 0.2656
# Epoch 2/50
# 15/15 [==============================] - 25s 2s/step - loss: 1.6604 - accuracy: 0.3594 - val_loss: 1.4309 - val_accuracy: 0.3958
# Epoch 3/50
# 15/15 [==============================] - 32s 2s/step - loss: 1.2663 - accuracy: 0.5268 - val_loss: 1.2215 - val_accuracy: 0.5312
# Epoch 4/50
# 15/15 [==============================] - 22s 1s/step - loss: 1.0488 - accuracy: 0.5648 - val_loss: 1.0577 - val_accuracy: 0.5365
# Epoch 5/50
# 15/15 [==============================] - 22s 1s/step - loss: 1.0009 - accuracy: 0.6109 - val_loss: 0.9939 - val_accuracy: 0.5833
# Epoch 6/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.8242 - accuracy: 0.6696 - val_loss: 0.8909 - val_accuracy: 0.5885
# Epoch 7/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.7665 - accuracy: 0.7016 - val_loss: 0.8326 - val_accuracy: 0.6302
# Epoch 8/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.7354 - accuracy: 0.7318 - val_loss: 0.6184 - val_accuracy: 0.7500
# Epoch 9/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.5939 - accuracy: 0.7880 - val_loss: 0.6512 - val_accuracy: 0.7396
# Epoch 10/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.6589 - accuracy: 0.7389 - val_loss: 0.6857 - val_accuracy: 0.6927
# Epoch 11/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.5395 - accuracy: 0.7911 - val_loss: 0.5887 - val_accuracy: 0.7448
# Epoch 12/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.5415 - accuracy: 0.8102 - val_loss: 0.7394 - val_accuracy: 0.6719
# Epoch 13/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.6047 - accuracy: 0.7819 - val_loss: 0.6214 - val_accuracy: 0.8021
# Epoch 14/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.6390 - accuracy: 0.7526 - val_loss: 0.5347 - val_accuracy: 0.8333
# Epoch 15/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.5496 - accuracy: 0.7813 - val_loss: 0.5901 - val_accuracy: 0.7604
# Epoch 16/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.4678 - accuracy: 0.8105 - val_loss: 0.4176 - val_accuracy: 0.8698
# Epoch 17/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.5321 - accuracy: 0.8172 - val_loss: 0.6891 - val_accuracy: 0.7448
# Epoch 18/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.4534 - accuracy: 0.8394 - val_loss: 0.4951 - val_accuracy: 0.7708
# Epoch 19/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.4358 - accuracy: 0.8347 - val_loss: 0.4633 - val_accuracy: 0.8281
# Epoch 20/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.4145 - accuracy: 0.8484 - val_loss: 0.4276 - val_accuracy: 0.8646
# Epoch 21/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.4428 - accuracy: 0.8451 - val_loss: 0.4300 - val_accuracy: 0.8594
# Epoch 22/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.3189 - accuracy: 0.8887 - val_loss: 0.3025 - val_accuracy: 0.9115
# Epoch 23/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.3923 - accuracy: 0.8499 - val_loss: 0.3218 - val_accuracy: 0.9010
# Epoch 24/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.3882 - accuracy: 0.8684 - val_loss: 0.4205 - val_accuracy: 0.8229
# Epoch 25/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.3962 - accuracy: 0.8504 - val_loss: 0.3429 - val_accuracy: 0.8750
# Epoch 26/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.2738 - accuracy: 0.9086 - val_loss: 0.4220 - val_accuracy: 0.8385
# Epoch 27/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.3965 - accuracy: 0.8537 - val_loss: 0.3689 - val_accuracy: 0.8438
# Epoch 28/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.3902 - accuracy: 0.8527 - val_loss: 0.3241 - val_accuracy: 0.8802
# Epoch 29/50
# 15/15 [==============================] - 43s 3s/step - loss: 0.4163 - accuracy: 0.8388 - val_loss: 0.3139 - val_accuracy: 0.9167
# Epoch 30/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.3240 - accuracy: 0.8727 - val_loss: 0.4584 - val_accuracy: 0.8854
# Epoch 31/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.3266 - accuracy: 0.8694 - val_loss: 0.3078 - val_accuracy: 0.8802
# Epoch 32/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.3220 - accuracy: 0.8676 - val_loss: 0.3927 - val_accuracy: 0.8594
# Epoch 33/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.3354 - accuracy: 0.8603 - val_loss: 0.2606 - val_accuracy: 0.9062
# Epoch 34/50
# 15/15 [==============================] - 32s 2s/step - loss: 0.3358 - accuracy: 0.8871 - val_loss: 0.3856 - val_accuracy: 0.8490
# Epoch 35/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.3225 - accuracy: 0.8766 - val_loss: 0.2719 - val_accuracy: 0.9115
# Epoch 36/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.3566 - accuracy: 0.8589 - val_loss: 0.2817 - val_accuracy: 0.9010
# Epoch 37/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.2186 - accuracy: 0.9186 - val_loss: 0.2005 - val_accuracy: 0.9271
# Epoch 38/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.1993 - accuracy: 0.9252 - val_loss: 0.2347 - val_accuracy: 0.9115
# Epoch 39/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.3573 - accuracy: 0.8714 - val_loss: 0.3647 - val_accuracy: 0.8594
# Epoch 40/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.3685 - accuracy: 0.8654 - val_loss: 0.5265 - val_accuracy: 0.8333
# Epoch 41/50
# 15/15 [==============================] - 19s 1s/step - loss: 0.5195 - accuracy: 0.8145 - val_loss: 0.4920 - val_accuracy: 0.8073
# Epoch 42/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.3996 - accuracy: 0.8507 - val_loss: 0.2930 - val_accuracy: 0.8958
# Epoch 43/50
# 15/15 [==============================] - 17s 1s/step - loss: 0.3501 - accuracy: 0.8858 - val_loss: 0.3778 - val_accuracy: 0.8958
# Epoch 44/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.3997 - accuracy: 0.8475 - val_loss: 0.2988 - val_accuracy: 0.9062
# Epoch 45/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.1965 - accuracy: 0.9177 - val_loss: 0.3236 - val_accuracy: 0.8490
# Epoch 46/50
# 15/15 [==============================] - 20s 1s/step - loss: 0.2441 - accuracy: 0.9045 - val_loss: 0.2697 - val_accuracy: 0.9010
# Epoch 47/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.1977 - accuracy: 0.9267 - val_loss: 0.1411 - val_accuracy: 0.9479
# Epoch 48/50
# 15/15 [==============================] - 17s 1s/step - loss: 0.2558 - accuracy: 0.9120 - val_loss: 0.1924 - val_accuracy: 0.9010
# Epoch 49/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.2612 - accuracy: 0.9000 - val_loss: 0.2049 - val_accuracy: 0.9323
# Epoch 50/50
# 15/15 [==============================] - 17s 1s/step - loss: 0.1774 - accuracy: 0.9383 - val_loss: 0.1163 - val_accuracy: 0.9792
